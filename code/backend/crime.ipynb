# %% [markdown]
# # **TK95348-Analysis and Prediction of Crime Hotspots using machine learning with Stacked Generalization Approach**

# %% [markdown]
# # **import librarys**

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Read The Dataset**

# %%
df = pd.read_excel("20230320020226crime_data_extended_entries.xlsx")

# %%
df.head()
# Out:
#         date time_of_day    crime_type         location  latitude  longitude  \
# 0 2021-12-18    21:29:18       Assault       Whitefield   13.1206    77.5712
# 1 2018-09-16    08:36:10       Forgery        Jayanagar   13.0680    77.5754
# 2 2018-06-02    04:27:36  Embezzlement      Koramangala   13.0788    77.6458
# 3 2020-02-24    10:51:00       Robbery  Electronic City   12.8899    77.5503
# 4 2018-06-02    08:01:24       Forgery      Indiranagar   13.0214    77.4496
#
#   victim_gender  victim_age perpetrator_gender  perpetrator_age weapon injury  \
# 0        Female          62              Other               18    Gun  Major
# 1          Male          56               Male               18   None  Fatal
# 2         Other          18               Male               20    Gun  Fatal
# 3          Male          25               Male               25    Gun  Minor
# 4          Male          53              Other               63  Knife   None
#
#          weather  temperature previous_activity
# 0  Partly Cloudy           40             Fraud
# 1  Partly Cloudy           10              None
# 2  Partly Cloudy            5           Robbery
# 3          Clear           25      Drug Offense
# 4          Clear           20             Fraud

# %%
df.tail()
# Out:
#           date time_of_day    crime_type         location  latitude  \
# 695 2018-02-14    08:29:36      Burglary     Marathahalli   13.0599
# 696 2019-06-14    14:51:19         Theft     Marathahalli   12.8068
# 697 2018-05-06    21:03:00       Forgery      Koramangala   12.8643
# 698 2019-09-01    05:44:25  Drug Offense  Electronic City   13.1407
# 699 2022-05-23    11:59:14     Vandalism     Banashankari   13.0282
#
#      longitude victim_gender  victim_age perpetrator_gender  perpetrator_age  \
# 695    77.4443         Other          26              Other               47
# 696    77.5564        Female          48               Male               33
# 697    77.6427         Other          35             Female               64
# 698    77.7683         Other          36              Other               47
# 699    77.6920          Male          19             Female               34
#
#            weapon injury        weather  temperature previous_activity
# 695          None   None  Partly Cloudy            3             Fraud
# 696          None  Minor           Rain            5              None
# 697  Blunt Object  Major           Rain           33             Fraud
# 698          None   None          Clear            4           Robbery
# 699         Knife   None  Partly Cloudy           16           Robbery

# %% [markdown]
# # **Information about data**

# %%
# shape of dataset
df.shape
# Out:
# (700, 15)

# %%
df["crime_type"].value_counts()
# Out:
# Robbery         89
# Embezzlement    82
# Burglary        80
# Vandalism       79
# Theft           78
# Assault         75
# Forgery         75
# Drug Offense    74
# Fraud           68
# Name: crime_type, dtype: int64

# %%
# datatype of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                700 non-null    datetime64[ns]
#  1   time_of_day         700 non-null    object
#  2   crime_type          700 non-null    object
#  3   location            700 non-null    object
#  4   latitude            700 non-null    float64
#  5   longitude           700 non-null    float64
#  6   victim_gender       700 non-null    object
#  7   victim_age          700 non-null    int64
#  8   perpetrator_gender  700 non-null    object
#  9   perpetrator_age     700 non-null    int64
#  10  weapon              700 non-null    object
#  11  injury              700 non-null    object
#  12  weather             700 non-null    object
#  13  temperature         700 non-null    int64
#  14  previous_activity   700 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(9)
# memory usage: 82.2+ KB

# %%
# check the null value
df.isnull().sum()
# Out:
# date                  0
# time_of_day           0
# crime_type            0
# location              0
# latitude              0
# longitude             0
# victim_gender         0
# victim_age            0
# perpetrator_gender    0
# perpetrator_age       0
# weapon                0
# injury                0
# weather               0
# temperature           0
# previous_activity     0
# dtype: int64

# %%
# Check The Duplicate Vlue
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 695    False
# 696    False
# 697    False
# 698    False
# 699    False
# Length: 700, dtype: bool

# %%
# Describe the Data
df.describe().T
# Out:
#                  count       mean        std      min        25%       50%  \
# latitude         700.0  13.002605   0.114179  12.8025  12.906950  13.00640
# longitude        700.0  77.605510   0.115468  77.4015  77.508875  77.60835
# victim_age       700.0  41.372857  13.980964  18.0000  29.000000  42.00000
# perpetrator_age  700.0  41.318571  14.014603  18.0000  29.000000  41.00000
# temperature      700.0  19.611429  11.823833   0.0000   9.000000  20.00000
#
#                       75%      max
# latitude         13.09755  13.1999
# longitude        77.70460  77.7992
# victim_age       54.00000  65.0000
# perpetrator_age  54.00000  65.0000
# temperature      30.00000  40.0000

# %%
sns.heatmap(df.describe().T)
# Out:
# <Axes: >

# %%
# Corrilation of Data
df.corr()
# Out:
# C:\Users\ymts0630\AppData\Local\Temp\ipykernel_4416\2796969102.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                  latitude  longitude  victim_age  perpetrator_age  temperature
# latitude         1.000000   0.017527    0.095357        -0.011823    -0.000325
# longitude        0.017527   1.000000    0.020296         0.001912    -0.015255
# victim_age       0.095357   0.020296    1.000000         0.011703    -0.014743
# perpetrator_age -0.011823   0.001912    0.011703         1.000000    -0.031204
# temperature     -0.000325  -0.015255   -0.014743        -0.031204     1.000000

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\ymts0630\AppData\Local\Temp\ipykernel_4416\58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                700 non-null    datetime64[ns]
#  1   time_of_day         700 non-null    object
#  2   crime_type          700 non-null    object
#  3   location            700 non-null    object
#  4   latitude            700 non-null    float64
#  5   longitude           700 non-null    float64
#  6   victim_gender       700 non-null    object
#  7   victim_age          700 non-null    int64
#  8   perpetrator_gender  700 non-null    object
#  9   perpetrator_age     700 non-null    int64
#  10  weapon              700 non-null    object
#  11  injury              700 non-null    object
#  12  weather             700 non-null    object
#  13  temperature         700 non-null    int64
#  14  previous_activity   700 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(9)
# memory usage: 82.2+ KB

# %% [markdown]
# # **EDA**

# %% [markdown]
# ## **Apply a Label Encoding**

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
# before applying LabelEncoding
df.head()
# Out:
#         date time_of_day    crime_type         location  latitude  longitude  \
# 0 2021-12-18    21:29:18       Assault       Whitefield   13.1206    77.5712
# 1 2018-09-16    08:36:10       Forgery        Jayanagar   13.0680    77.5754
# 2 2018-06-02    04:27:36  Embezzlement      Koramangala   13.0788    77.6458
# 3 2020-02-24    10:51:00       Robbery  Electronic City   12.8899    77.5503
# 4 2018-06-02    08:01:24       Forgery      Indiranagar   13.0214    77.4496
#
#   victim_gender  victim_age perpetrator_gender  perpetrator_age weapon injury  \
# 0        Female          62              Other               18    Gun  Major
# 1          Male          56               Male               18   None  Fatal
# 2         Other          18               Male               20    Gun  Fatal
# 3          Male          25               Male               25    Gun  Minor
# 4          Male          53              Other               63  Knife   None
#
#          weather  temperature previous_activity
# 0  Partly Cloudy           40             Fraud
# 1  Partly Cloudy           10              None
# 2  Partly Cloudy            5           Robbery
# 3          Clear           25      Drug Offense
# 4          Clear           20             Fraud

# %%
col = df[["time_of_day",'crime_type','location','victim_gender','perpetrator_gender','weapon','injury','weather','previous_activity']]

# %%
for i in col:
    df[i]=le.fit_transform(df[i])

# %%
# After applying LabelEncoding
df.head()
# Out:
#         date  time_of_day  crime_type  location  latitude  longitude  \
# 0 2021-12-18          627           0        10   13.1206    77.5712
# 1 2018-09-16          243           4         6   13.0680    77.5754
# 2 2018-06-02          128           3         8   13.0788    77.6458
# 3 2020-02-24          298           6         2   12.8899    77.5503
# 4 2018-06-02          223           4         4   13.0214    77.4496
#
#    victim_gender  victim_age  perpetrator_gender  perpetrator_age  weapon  \
# 0              0          62                   2               18       1
# 1              1          56                   1               18       3
# 2              2          18                   1               20       1
# 3              1          25                   1               25       1
# 4              1          53                   2               63       2
#
#    injury  weather  temperature  previous_activity
# 0       1        2           40                  5
# 1       0        2           10                  6
# 2       0        2            5                  7
# 3       2        0           25                  2
# 4       3        0           20                  5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                700 non-null    datetime64[ns]
#  1   time_of_day         700 non-null    int32
#  2   crime_type          700 non-null    int32
#  3   location            700 non-null    int32
#  4   latitude            700 non-null    float64
#  5   longitude           700 non-null    float64
#  6   victim_gender       700 non-null    int32
#  7   victim_age          700 non-null    int64
#  8   perpetrator_gender  700 non-null    int32
#  9   perpetrator_age     700 non-null    int64
#  10  weapon              700 non-null    int32
#  11  injury              700 non-null    int32
#  12  weather             700 non-null    int32
#  13  temperature         700 non-null    int64
#  14  previous_activity   700 non-null    int32
# dtypes: datetime64[ns](1), float64(2), int32(9), int64(3)
# memory usage: 57.5 KB

# %%
# Histplot of every column in dataset
df1=df.select_dtypes(exclude=['object','bool'])
for column in df1:
        plt.figure(figsize=(17,1))
        sns.histplot(data=df1, x=column)
plt.show()

# %%
# countplot of every column in dataset
df1=df.select_dtypes(exclude=['object','bool'])
for column in df1:
        plt.figure(figsize=(17,1))
        sns.countplot(data=df1, x=column)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                700 non-null    datetime64[ns]
#  1   time_of_day         700 non-null    int32
#  2   crime_type          700 non-null    int32
#  3   location            700 non-null    int32
#  4   latitude            700 non-null    float64
#  5   longitude           700 non-null    float64
#  6   victim_gender       700 non-null    int32
#  7   victim_age          700 non-null    int64
#  8   perpetrator_gender  700 non-null    int32
#  9   perpetrator_age     700 non-null    int64
#  10  weapon              700 non-null    int32
#  11  injury              700 non-null    int32
#  12  weather             700 non-null    int32
#  13  temperature         700 non-null    int64
#  14  previous_activity   700 non-null    int32
# dtypes: datetime64[ns](1), float64(2), int32(9), int64(3)
# memory usage: 57.5 KB

# %%
# Target column lineplot
sns.lineplot(df["crime_type"])
# Out:
# <Axes: ylabel='crime_type'>

# %%
# Target column lineplot
sns.barplot(df["crime_type"])
# Out:
# <Axes: >

# %%
# Target column lineplot
sns.histplot(df["crime_type"])
# Out:
# <Axes: xlabel='crime_type', ylabel='Count'>

# %%
# target column kdeplot
sns.kdeplot(df["crime_type"])
# Out:
# <Axes: xlabel='crime_type', ylabel='Density'>

# %%
# pairplot of every column in dataset
sns.pairplot(df)

# %% [markdown]
# # **Preprocessing**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                700 non-null    datetime64[ns]
#  1   time_of_day         700 non-null    int32
#  2   crime_type          700 non-null    int32
#  3   location            700 non-null    int32
#  4   latitude            700 non-null    float64
#  5   longitude           700 non-null    float64
#  6   victim_gender       700 non-null    int32
#  7   victim_age          700 non-null    int64
#  8   perpetrator_gender  700 non-null    int32
#  9   perpetrator_age     700 non-null    int64
#  10  weapon              700 non-null    int32
#  11  injury              700 non-null    int32
#  12  weather             700 non-null    int32
#  13  temperature         700 non-null    int64
#  14  previous_activity   700 non-null    int32
# dtypes: datetime64[ns](1), float64(2), int32(9), int64(3)
# memory usage: 57.5 KB

# %%
df.isnull().sum()
# Out:
# date                  0
# time_of_day           0
# crime_type            0
# location              0
# latitude              0
# longitude             0
# victim_gender         0
# victim_age            0
# perpetrator_gender    0
# perpetrator_age       0
# weapon                0
# injury                0
# weather               0
# temperature           0
# previous_activity     0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
#Delete a unknown column
df.drop("date",axis=1,inplace=True)
df.drop("time_of_day",axis=1,inplace=True)

# %%
df["crime_type"].value_counts()
# Out:
# 6    89
# 3    82
# 1    80
# 8    79
# 7    78
# 0    75
# 4    75
# 2    74
# 5    68
# Name: crime_type, dtype: int64

# %% [markdown]
# ## **Split The Data**

# %% [markdown]
# ### **Applying the Smote Methos**

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
x = df.drop(['crime_type'], axis = 1) 
y = df['crime_type']

# %%
Oversample = RandomOverSampler(random_state=72)
x_sm, y_sm = Oversample.fit_resample(x[:100],y[:100])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x_sm, y_sm, test_size = 0.3, random_state= 72)

# %%
x_train.shape
# Out:
# (94, 12)

# %%
x_test.shape
# Out:
# (41, 12)

# %%
y_train.shape
# Out:
# (94,)

# %% [markdown]
# # **Module Train**

# %%
from sklearn.metrics import accuracy_score

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   crime_type          700 non-null    int32
#  1   location            700 non-null    int32
#  2   latitude            700 non-null    float64
#  3   longitude           700 non-null    float64
#  4   victim_gender       700 non-null    int32
#  5   victim_age          700 non-null    int64
#  6   perpetrator_gender  700 non-null    int32
#  7   perpetrator_age     700 non-null    int64
#  8   weapon              700 non-null    int32
#  9   injury              700 non-null    int32
#  10  weather             700 non-null    int32
#  11  temperature         700 non-null    int64
#  12  previous_activity   700 non-null    int32
# dtypes: float64(2), int32(8), int64(3)
# memory usage: 49.3 KB

# %% [markdown]
# ## **RendomForestClasifier**

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
k = 5
kf = KFold(n_splits=k, shuffle=True)

# %%
from sklearn.ensemble import RandomForestClassifier
re = RandomForestClassifier(random_state=72)
re.fit(x_train,y_train)
re_pred = re.predict(x_test)
ac = accuracy_score(y_test,re_pred)
ac
# Out:
# 0.4878048780487805

# %% [markdown]
# ## **DecisionTreeClasifier**

# %%
from sklearn.tree import DecisionTreeClassifier
de = DecisionTreeClassifier()
de.fit(x_train,y_train)
de_pred = de.predict(x_test)
ac1 = accuracy_score(y_test,de_pred)
ac1
# Out:
# 0.43902439024390244

# %% [markdown]
# ## **GradientBoostingClassifier**

# %%
from sklearn.ensemble import GradientBoostingClassifier
gd = GradientBoostingClassifier()
gd.fit(x_train,y_train)
gd_pred = gd.predict(x_test)
bc = accuracy_score(y_test,gd_pred)
bc
# Out:
# 0.4634146341463415

# %% [markdown]
# # **Prediction**

# %%
df.head()
# Out:
#    crime_type  location  latitude  longitude  victim_gender  victim_age  \
# 0           0        10   13.1206    77.5712              0          62
# 1           4         6   13.0680    77.5754              1          56
# 2           3         8   13.0788    77.6458              2          18
# 3           6         2   12.8899    77.5503              1          25
# 4           4         4   13.0214    77.4496              1          53
#
#    perpetrator_gender  perpetrator_age  weapon  injury  weather  temperature  \
# 0                   2               18       1       1        2           40
# 1                   1               18       3       0        2           10
# 2                   1               20       1       0        2            5
# 3                   1               25       1       2        0           25
# 4                   2               63       2       3        0           20
#
#    previous_activity
# 0                  5
# 1                  6
# 2                  7
# 3                  2
# 4                  5

# %%
input = [[10	,13.1206,	77.5712,	0	,62,	2	,18	,1	,1,	2,	40,	5]]

# %%
input1 = [[8	,13.0788	,77.6458,	2	,18	,1,	20,	1	,0	,2,	5	,7]]

# %%
out = gd.predict(input)
# Out:
# C:\Users\ymts0630\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but GradientBoostingClassifier was fitted with feature names
#   warnings.warn(

# %%
out1 = gd.predict(input1)
# Out:
# C:\Users\ymts0630\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but GradientBoostingClassifier was fitted with feature names
#   warnings.warn(

# %%
out1
# Out:
# array([3])

# %%
if out == 0:
    print('Robbery')
elif out == 1:
    print('Embezzlement')
elif out == 2:
    print('Burglary')
elif out == 3:
    print('Vandalism')
elif out == 4:
    print('Theft')
elif out == 5:
    print('Assault')
elif out == 6:
    print('Forgery')
elif out == 7:
    print('Drug Offense')
else:
    print('Fraud')
# Out:
# Robbery

# %%
if out1 == 0:
    print('Robbery')
elif out1 == 1:
    print('Embezzlement')
elif out1 == 2:
    print('Burglary')
elif out1 == 3:
    print('Vandalism')
elif out1 == 4:
    print('Theft')
elif out1 == 5:
    print('Assault')
elif out1 == 6:
    print('Forgery')
elif out1 == 7:
    print('Drug Offense')
else:
    print('Fraud')
# Out:
# Vandalism

# %%
import folium

# Bangalore latitude and longitude
lat, lon = 13.1206, 77.5715

# Create a map centered on Bangalore
map_bangalore = folium.Map(location=[lat, lon], zoom_start=13)

# Add a marker for Bangalore
folium.Marker([lat, lon], tooltip='Bangalore').add_to(map_bangalore)

# Display the map
m = map_bangalore

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_01f2d7aab6c14ce3de3da6f754cea281 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_01f2d7aab6c14ce3de3da6f754cea281&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_01f2d7aab6c14ce3de3da6f754cea281 = L.map(
#                 &quot;map_01f2d7aab6c14ce3de3da6f754cea281&quot;,
#                 {
#                     center: [13.1206, 77.5715],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c0b8d21a58ae9d5a525abc3af87d3990 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_01f2d7aab6c14ce3de3da6f754cea281);
#
#
#             var marker_656a1fed7e5025898d1f75a15b1bc5f0 = L.marker(
#                 [13.1206, 77.5715],
#                 {}
#             ).addTo(map_01f2d7aab6c14ce3de3da6f754cea281);
#
#
#             marker_656a1fed7e5025898d1f75a15b1bc5f0.bindTooltip(
#                 `&lt;div&gt;
#                      Bangalore
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # **Accuracy Graph**

# %%
graph = pd.DataFrame({'Modules':['RendomForestClasifier','DecisionTreeClassifier','GradientBoostingClassifier'],
          'Accuracy':[ac*100,ac1*100,bc*100]})

# %%
graph
# Out:
#                       Modules   Accuracy
# 0       RendomForestClasifier  48.780488
# 1      DecisionTreeClassifier  43.902439
# 2  GradientBoostingClassifier  46.341463

# %%
plt.figure(figsize=(7,6))
sns.barplot(y=graph.Accuracy,x=graph.Modules)
plt.xticks(rotation='vertical')
plt.show()
